# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
cleaned_Data = pd.read_csv('data/standardised_2019.csv').drop(columns=["Unnamed: 0"])
cleaned_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  125 non-null    object
#  1   Healthy Life Expectancy  125 non-null    float64
#  2   Happiness Score          125 non-null    float64
#  3   Peaceful Index           125 non-null    float64
#  4   Education                125 non-null    float64
#  5   Unemployment Rate        125 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 6.0+ KB

# %%
cleaned_Data.describe()
# Out:
#        Healthy Life Expectancy  Happiness Score  Peaceful Index   Education  \
# count               125.000000       125.000000      125.000000  125.000000
# mean                 -0.224345         5.456376        0.641169   -0.289557
# std                   0.184654         1.124551        0.212374    0.141965
# min                  -0.615656         2.853000        0.088388   -0.580654
# 25%                  -0.371984         4.559000        0.501930   -0.406715
# 50%                  -0.181038         5.425000        0.642449   -0.280691
# 75%                  -0.112046         6.199000        0.772350   -0.174158
# max                   0.146636         7.769000        1.167773   -0.056161
#
#        Unemployment Rate
# count         125.000000
# mean            2.293014
# std             1.364875
# min            -1.650551
# 25%             1.532171
# 50%             2.088419
# 75%             3.198534
# max             5.851698

# %%
cleaned_Data.head()
# Out:
#        Country  Healthy Life Expectancy  Happiness Score  Peaceful Index  \
# 0  Afghanistan                -0.506777            3.203        1.167773
# 1      Albania                -0.121327            4.719        0.546120
# 2      Algeria                -0.201204            5.211        0.763603
# 3    Argentina                -0.114836            6.086        0.655381
# 4      Armenia                -0.174834            4.559        0.734692
#
#    Education  Unemployment Rate
# 0  -0.487112           3.585536
# 1  -0.236739           3.632569
# 2  -0.298792           3.450668
# 3  -0.139487           3.315755
# 4  -0.241893           4.695523

# %% [markdown]
# ## Heat map

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(cleaned_Data.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar charts of each variable

# %%
hle = cleaned_Data.sort_values(by='Healthy Life Expectancy')
hle.tail(10)
# Out:
#          Country  Healthy Life Expectancy  Happiness Score  Peaceful Index  \
# 54        Israel                 0.029242            7.139        0.943492
# 5      Australia                 0.036373            7.228        0.364247
# 22        Canada                 0.039437            7.278        0.285456
# 55         Italy                 0.039437            6.223        0.499712
# 30        Cyprus                 0.042507            6.046        0.606746
# 38        France                 0.045581            6.592        0.606746
# 110  Switzerland                 0.052776            7.480        0.292608
# 107        Spain                 0.063101            6.354        0.501930
# 57         Japan                 0.090211            5.886        0.327485
# 103    Singapore                 0.146636            6.262        0.291895
#
#      Education  Unemployment Rate
# 54   -0.113428           1.650358
# 5    -0.074504           2.133764
# 22   -0.103074           2.289074
# ...

# %%
hle_bar = hle.tail(10)[['Country', 'Healthy Life Expectancy']]
ind = hle_bar.set_index("Country", inplace = True)
barh = hle_bar.plot(kind='barh',figsize=(30, 16), color = "red", legend = None)
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.xlabel("Life Expectancy", fontsize = 22)
plt.ylabel("Countries", fontsize = 22)
plt.title("Countries with the highest life expectancies", fontsize=32)
barh.spines['top'].set_visible(False)
barh.spines['right'].set_visible(False)
barh.spines['bottom'].set_linewidth(0.5)
barh.spines['left'].set_visible(True)
plt.show()

# %%
happiness = cleaned_Data.sort_values(by='Happiness Score')
happiness.tail(10)
# Out:
#          Country  Healthy Life Expectancy  Happiness Score  Peaceful Index  \
# 6        Austria                 0.016074            7.246        0.224417
# 22        Canada                 0.039437            7.278        0.285456
# 83   New Zealand                 0.026195            7.307        0.204902
# 109       Sweden                 0.009023            7.343        0.396950
# 110  Switzerland                 0.052776            7.480        0.292608
# 82   Netherlands                -0.001000            7.488        0.383639
# 49       Iceland                 0.026195            7.494        0.088388
# 88        Norway                 0.028226            7.554        0.377869
# 31       Denmark                -0.003995            7.600        0.236676
# 37       Finland                -0.013943            7.769        0.349070
#
#      Education  Unemployment Rate
# 6    -0.130230           1.908359
# 22   -0.103074           2.289074
# 83   -0.072582           1.769975
# ...

# %%
happiness_bar = happiness.tail(10)[['Country', 'Happiness Score']]
ind = happiness_bar.set_index("Country", inplace = True)
barh = happiness_bar.plot(kind='barh',figsize=(30, 16), color = "green", legend = None)
barh
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.xlabel("Happiness Score", fontsize = 22)
plt.ylabel("Country", fontsize = 22)
plt.title("Countries with the highest happiness score", fontsize=32)
barh.spines['top'].set_visible(False)
barh.spines['right'].set_visible(False)
barh.spines['bottom'].set_linewidth(0.5)
barh.spines['left'].set_visible(True)
plt.show()

# %%
peace = cleaned_Data.sort_values(by='Peaceful Index')
peace.tail(10)
# Out:
#                       Country  Healthy Life Expectancy  Happiness Score  \
# 86                    Nigeria                -0.564870            5.265
# 63                    Lebanon                -0.174834            5.197
# 118                   Ukraine                -0.240516            4.332
# 115                    Turkey                -0.181038            5.373
# 89                   Pakistan                -0.397546            5.653
# 66                      Libya                -0.294483            5.525
# 23   Central African Republic                -0.615656            3.083
# 52                       Iraq                -0.369810            4.437
# 106               South Sudan                -0.541417            2.853
# 0                 Afghanistan                -0.506777            3.203
#
#      Peaceful Index  Education  Unemployment Rate
# 86         0.950124  -0.430225           3.033599
# 63         0.965071  -0.352817           3.610352
# ...

# %%
peace_bar = peace.tail(10)[['Country', 'Peaceful Index']]
ind = peace_bar.set_index("Country", inplace = True)
barh = peace_bar.plot(kind='barh',figsize=(30, 16), color = "green", legend = None)
barh
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.xlabel("Peace Index", fontsize = 22)
plt.ylabel("Country", fontsize = 22)
plt.title("Countries with the highest peace index scores", fontsize=32)
barh.spines['top'].set_visible(False)
barh.spines['right'].set_visible(False)
barh.spines['bottom'].set_linewidth(0.5)
barh.spines['left'].set_visible(True)
plt.show()

# %%
education = cleaned_Data.sort_values(by='Education')
education.tail(10)
# Out:
#             Country  Healthy Life Expectancy  Happiness Score  Peaceful Index  \
# 109          Sweden                 0.009023            7.343        0.396950
# 31          Denmark                -0.003995            7.600        0.236676
# 53          Ireland                -0.001000            7.021        0.317172
# 5         Australia                 0.036373            7.228        0.364247
# 49          Iceland                 0.026195            7.494        0.088388
# 83      New Zealand                 0.026195            7.307        0.204902
# 37          Finland                -0.013943            7.769        0.349070
# 120  United Kingdom                -0.003995            7.054        0.521085
# 88           Norway                 0.028226            7.554        0.377869
# 41          Germany                -0.012951            6.985        0.427204
#
#      Education  Unemployment Rate
# 109  -0.080256           2.618528
# 31   -0.078341           2.088419
# ...

# %%
education_bar = education.tail(10)[['Country', 'Education']]
ind = education_bar.set_index("Country", inplace = True)
barh = education_bar.plot(kind='barh',figsize=(30, 16), color = "green", legend = None)
barh
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.xlabel("Education Index", fontsize = 22)
plt.ylabel("Country", fontsize = 22)
plt.title("Countries with the highest education index", fontsize=32)
barh.spines['top'].set_visible(False)
barh.spines['right'].set_visible(False)
barh.spines['bottom'].set_linewidth(0.5)
barh.spines['left'].set_visible(True)
plt.show()

# %%
unemployment = cleaned_Data.sort_values(by='Unemployment Rate')
unemployment.tail(10)
# Out:
#              Country  Healthy Life Expectancy  Happiness Score  \
# 58            Jordan                -0.174834            4.906
# 87   North Macedonia                -0.154233            5.274
# 43            Greece                -0.001000            5.287
# 4            Armenia                -0.174834            4.559
# 66             Libya                -0.294483            5.525
# 80           Namibia                -0.436666            4.639
# 39             Gabon                -0.371984            4.799
# 64           Lesotho                -0.595769            3.802
# 15          Botswana                -0.395453            3.488
# 105     South Africa                -0.441856            4.722
#
#      Peaceful Index  Education  Unemployment Rate
# 58         0.633082  -0.302864           4.490771
# 87         0.595472  -0.272365           4.553891
# 43         0.629304  -0.145015           4.560833
# 4          0.734692  -0.241893           4.695523
# ...

# %%
unemployment_bar = unemployment.tail(10)[['Country', 'Unemployment Rate']]
ind = unemployment_bar.set_index("Country", inplace = True)
barh = unemployment_bar.plot(kind='barh',figsize=(30, 16), color = "green", legend = None)
barh
plt.yticks(fontsize = 24)
plt.xticks(ind,fontsize = 18)
plt.xlabel("Unemployment rate(%)", fontsize = 22)
plt.ylabel("Country", fontsize = 22)
plt.title("Countires with the highest unemployment rate", fontsize=32)
barh.spines['top'].set_visible(False)
barh.spines['right'].set_visible(False)
barh.spines['bottom'].set_linewidth(0.5)
barh.spines['left'].set_visible(True)
plt.show()

# %% [markdown]
# ## Joint plot between Happiness and life expectancy

# %%
sb.jointplot(data = cleaned_Data, x = "Happiness Score", y = "Healthy Life Expectancy", height = 12)

# %% [markdown]
# ## Uni-variate linear regression between happiness and life expectancy

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(cleaned_Data['Happiness Score'])
X = pd.DataFrame(cleaned_Data['Healthy Life Expectancy'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (100, 1) (100, 1)
# Test Set  : (25, 1) (25, 1)

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [6.66254981]
# Coefficients 	: a =  [[5.34554162]]

# %% [markdown]
# ## Train Set

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
# Explained Variance in simply the "Score"
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
# Out:
# Explained Variance (R^2) 	: 0.7031179662968634

# %%
# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
# Out:
# Mean Squared Error (MSE) 	: 0.38440645767568504

# %%
# Predict Happiness Score corresponding to Life Expectancy
y_test_pred = linreg.predict(X_test)

# %% [markdown]
# ## Test Set

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %%
# Compute MSE on the test set
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
# Out:
# Mean Squared Error (MSE) 	: 0.5513015509146328

# %% [markdown]
# ## Multi-variate linear regression

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(cleaned_Data['Happiness Score'])
X = pd.DataFrame(cleaned_Data[['Healthy Life Expectancy','Peaceful Index','Education', 'Unemployment Rate']])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(X_train, y_train)
# Out:
# Train Set : (100, 4) (100, 1)
# Test Set  : (25, 4) (25, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [7.20983468]
# Coefficients 	: a =  [[ 3.61259414  0.08752005  2.23213945 -0.13828391]]

# %%
# Predict Happiness Score values corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(y_train, y_train_pred))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(y_test, y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.7066444894307669
# Mean Squared Error (MSE) on Train Set 	: 0.35991404102748015
# Mean Squared Error (MSE) on Test Set 	: 0.3689400338784812
